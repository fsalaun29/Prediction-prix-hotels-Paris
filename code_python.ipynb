# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
path = os.getcwd()
os.chdir(path)

# %%
df_projet =pd.read_excel("./hotels.xlsx") # lecture des données

# %%
df_projet # visulisation des données
# Out:
#       Id                                             Hôtels Note moyenne  \
# 0      1                                         Vice Versa          7,9
# 1      2                                    Le Robinet d'Or          9,0
# 2      3                                       Hôtel Gaston          8,2
# 3      4                    Absolute Hotel Paris République          7,9
# 4      5                                    The ReMIX Hotel          8,4
# 5      6                            TRIBE Paris Batignolles          9,1
# 6      7                            Hôtel Des Arts-Bastille          7,7
# 7      8                                  Hotel Aida Marais          7,9
# 8      9                             Hôtel Hor Les Lumières          8,6
# 9     10                                   Hotel Aida Opera          8,3
# 10    11                                        Maxim Opéra          8,3
# 11    12                                        Hotel Bloum          8,1
# ...

# %%
df_projet.dtypes
# Out:
# Id                         int64
# Hôtels                    object
# Note moyenne              object
# Nombre de commentaires    object
# Prix                       int64
# Arrondissement            object
# dtype: object

# %%
print (df_projet.describe())
# Out:
#                Id         Prix
# count  797.000000   797.000000
# mean   399.000000   175.900878
# std    230.218375   107.157865
# min      1.000000    68.000000
# 25%    200.000000   123.000000
# 50%    399.000000   151.000000
# 75%    598.000000   204.000000
# max    797.000000  1430.000000

# %%
print(df_projet.groupby('Arrondissement')['Hôtels'].count())
# Out:
#   File "<ipython-input-36-c8322e1ab7de>", line 1
#     print(plt(df_projet.groupby('Arrondissement')['Hôtels'].count())
#                                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
df_projet['Prix'].hist(bins=50, normed=True)
# Out:
# C:\Users\KOUAME YAO\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
